# %%
# Authors: Gael Varoquaux, Nelle Varoquaux
# License: BSD 3 clause

import time
import matplotlib.pyplot as plt
import numpy as np

from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import kneighbors_graph

# %%
import pandas as pd

df = pd.read_csv('s1.txt', delim_whitespace=True)
X=np.asarray(df)

# %%
# Create a graph capturing local connectivity. Larger number of neighbors
# will give more homogeneous clusters to the cost of computation
# time. A very large number of neighbors gives more evenly distributed
# cluster sizes, but may not impose the local manifold structure of
# the data
knn_graph = kneighbors_graph(X, 30, include_self=False)

for connectivity in (None, knn_graph):
    for n_clusters in (9, 12, 15, 18, 21):
        plt.figure(figsize=(10, 4))
        for index, linkage in enumerate(('average',
                                         'complete',
                                         'ward')):
            plt.subplot(1, 4, index + 1)
            model = AgglomerativeClustering(linkage=linkage,
                                            connectivity=connectivity,
                                            n_clusters=n_clusters)
            t0 = time.time()
            model.fit(X)
            elapsed_time = time.time() - t0
            plt.scatter(X[:, 0], X[:, 1], c=model.labels_,
                        cmap=plt.cm.nipy_spectral)
            plt.title('linkage=%s\n(time %.2fs)' % (linkage, elapsed_time),
                      fontdict=dict(verticalalignment='top'))
           
            ### Performance Evaluation
            ##1. silhouette_score
            from sklearn.metrics import silhouette_score
            score_sil = silhouette_score(df, model.labels_) 
            print(score_sil)
            
            ##2. calinski_harabaz_score
            from sklearn.metrics import calinski_harabaz_score
            score_ch = calinski_harabaz_score(df, model.labels_) 
            print(score_ch)
            
            ##3. davies_bouldin_score
            from sklearn.metrics import davies_bouldin_score
            score_db = davies_bouldin_score(df, model.labels_) 
            print(score_db)
            
            plt.axis('equal')
            plt.axis('off')

            plt.subplots_adjust(bottom=0, top=.89, wspace=0,
                                left=0, right=1)
            plt.suptitle('n_cluster=%i, connectivity=%r' %
                         (n_clusters, connectivity is not None), size=17)
            
            


plt.show()
# Out:
# 0.580855022363353
# 8141.145224871632
# 0.6040069558054331
# /Users/roswal/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# 0.5429200160813151
# 7284.871648495587
# 0.6675308024369365
# /Users/roswal/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# 0.5829538628855502
# 8216.199630916239
# 0.6033578250050842
# /Users/roswal/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# 0.6353392491546875
# 10732.16859043623
# 0.4966153344354755
# ...

# %%
### Performance Evaluation
##1. silhouette_score
from sklearn.metrics import silhouette_score
score_sil = silhouette_score(df, model.labels_) 
score_sil
# Out:
# 0.5561229465514939

# %%
##2. calinski_harabaz_score
from sklearn.metrics import calinski_harabaz_score
score_ch = calinski_harabaz_score(df, model.labels_) 
score_ch
# Out:
# 18384.643315190504

# %%
##3. davies_bouldin_score
from sklearn.metrics import davies_bouldin_score
score_db = davies_bouldin_score(df, model.labels_) 
score_db
# Out:
# /Users/roswal/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# 0.7871407379100775

# %%
##Multi-dimensional data 

df_dim2 = pd.read_csv('dim2.txt', delim_whitespace=True)
X2=np.asarray(df_dim2)

df_dim5 = pd.read_csv('dim5.txt', delim_whitespace=True)
X5=np.asarray(df_dim5)

df_dim10 = pd.read_csv('dim10.txt', delim_whitespace=True)
X10=np.asarray(df_dim10)

df_dim15 = pd.read_csv('dim15.txt', delim_whitespace=True)
X15=np.asarray(df_dim15)

# %%
#Half dataset
df2_half=df_dim2.loc[:674]
X2_half=np.asarray(df2_half)

df5_half=df_dim5.loc[:1687]
X5_half=np.asarray(df5_half)

df10_half=df_dim10.loc[:3374]
X10_half=np.asarray(df10_half)

df15_half=df_dim15.loc[:6749]
X15_half=np.asarray(df15_half)

# %%
# Create a graph capturing local connectivity. Larger number of neighbors
# will give more homogeneous clusters to the cost of computation
# time. A very large number of neighbors gives more evenly distributed
# cluster sizes, but may not impose the local manifold structure of
# the data
knn_graph = kneighbors_graph(X2_half, 10, include_self=False)

for connectivity in (None, knn_graph):
        plt.figure(figsize=(10, 4))
        for index, linkage in enumerate(('average',
                                         'complete',
                                         'ward')):
            plt.subplot(1, 4, index + 1)
            model = AgglomerativeClustering(linkage=linkage,
                                            connectivity=connectivity,
                                            n_clusters=5)
            t0 = time.time()
            model.fit(X2_half)
            elapsed_time = time.time() - t0
            plt.scatter(X2_half[:, 0], X2_half[:, 1], c=model.labels_,
                        cmap=plt.cm.nipy_spectral)
            plt.title('linkage=%s\n(time %.2fs)' % (linkage, elapsed_time),
                      fontdict=dict(verticalalignment='top'))
           
            ### Performance Evaluation
            ##1. silhouette_score
            from sklearn.metrics import silhouette_score
            score_sil = silhouette_score(df2_half, model.labels_) 
            print('sil_score is ' + str(score_sil))
            
            ##2. calinski_harabaz_score
            from sklearn.metrics import calinski_harabaz_score
            score_ch = calinski_harabaz_score(df2_half, model.labels_) 
            print('ch_score is ' + str(score_ch))
            
            ##3. davies_bouldin_score
            from sklearn.metrics import davies_bouldin_score
            score_db = davies_bouldin_score(df2_half, model.labels_) 
            print('db_score is ' + str(score_db))
            
            plt.axis('equal')
            plt.axis('off')

            plt.subplots_adjust(bottom=0, top=.89, wspace=0,
                                left=0, right=1)
            plt.suptitle('n_cluster=%i, connectivity=%r' %
                         (n_clusters, connectivity is not None), size=17)
            
            


plt.show()
# Out:
# /Users/roswal/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /Users/roswal/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: invalid value encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /Users/roswal/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /Users/roswal/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: invalid value encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# sil_score is 0.8359392011726308
# ch_score is 2427.0909693992326
# ...

# %%
# Create a graph capturing local connectivity. Larger number of neighbors
# will give more homogeneous clusters to the cost of computation
# time. A very large number of neighbors gives more evenly distributed
# cluster sizes, but may not impose the local manifold structure of
# the data
knn_graph = kneighbors_graph(X5_half, n_neighbors=10, include_self=False)


plt.figure(figsize=(10, 4))

plt.subplot(1, 4, index + 1)
t0 = time.time()
ward = AgglomerativeClustering(n_clusters=5, linkage='ward').fit(X5_half)

elapsed_time = time.time() - t0
plt.scatter(X5_half[:, 0], X5_half[:, 1], c=ward.labels_, cmap=plt.cm.nipy_spectral)
#plt.title('linkage=%s\n(time %.2fs)' % (linkage, elapsed_time), fontdict=dict(verticalalignment='top'))
plt.title('Time is ' + str(elapsed_time))

### Performance Evaluation
##1. silhouette_score
from sklearn.metrics import silhouette_score
score_sil = silhouette_score(df5_half, ward.labels_) 
print('sil_score is ' + str(score_sil))
            
##2. calinski_harabaz_score
from sklearn.metrics import calinski_harabaz_score
score_ch = calinski_harabaz_score(df5_half, ward.labels_) 
print('ch_score is ' + str(score_ch))
            
##3. davies_bouldin_score
from sklearn.metrics import davies_bouldin_score
score_db = davies_bouldin_score(df5_half, ward.labels_) 
print('db_score is ' + str(score_db))
            
plt.axis('equal')
plt.axis('off')

plt.subplots_adjust(bottom=0, top=.89, wspace=0,left=0, right=1)
plt.suptitle('n_cluster=5, connectivity=False')
            
plt.show()
# Out:
# sil_score is 0.9391922769236488
# ch_score is 103364.18162791427
# db_score is 0.08249242314911417
# /Users/roswal/anaconda3/lib/python3.6/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances

# %%
# Authors : Vincent Michel, 2010
#           Alexandre Gramfort, 2010
#           Gael Varoquaux, 2010
# License: BSD 3 clause

print(__doc__)

import time as time
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
from sklearn.cluster import AgglomerativeClustering
from sklearn.datasets.samples_generator import make_swiss_roll

# #############################################################################
# Generate data (swiss roll dataset)
#n_samples = 1500
#noise = 0.05
#X, _ = make_swiss_roll(n_samples, noise)
# Make it thinner
#X[:, 1] *= .5

X = pd.read_csv('dim5.txt', delim_whitespace=True)
df_dim5 =np.asarray(X)

# #############################################################################
# Compute clustering
print("Compute unstructured hierarchical clustering...")
st = time.time()
ward = AgglomerativeClustering(n_clusters=9, linkage='ward').fit(df_dim5)
elapsed_time = time.time() - st
label = ward.labels_
print("Elapsed time: %.2fs" % elapsed_time)
print("Number of points: %i" % label.size)

# #############################################################################
# Plot result
fig = plt.figure()
ax = p3.Axes3D(fig)
ax.view_init(7, -80)
for l in np.unique(label):
    ax.scatter(df_dim5[label == l, 0], df_dim5[label == l, 1], df_dim5[label == l, 2],
               color=plt.cm.jet(np.float(l) / np.max(label + 1)),
               s=20, edgecolor='k')
plt.title('Without connectivity constraints (time %.2fs)' % elapsed_time)


# #############################################################################
# Define the structure A of the data. Here a 10 nearest neighbors
from sklearn.neighbors import kneighbors_graph
connectivity = kneighbors_graph(df_dim5, n_neighbors=10, include_self=False)

# #############################################################################
# Compute clustering
print("Compute structured hierarchical clustering...")
st = time.time()
ward = AgglomerativeClustering(n_clusters=6, connectivity=connectivity,
                               linkage='ward').fit(df_dim5)
elapsed_time = time.time() - st
label = ward.labels_
print("Elapsed time: %.2fs" % elapsed_time)
print("Number of points: %i" % label.size)

# #############################################################################
# Plot result
fig = plt.figure()
ax = p3.Axes3D(fig)
ax.view_init(7, -80)
for l in np.unique(label):
    ax.scatter(df_dim5[label == l, 0], df_dim5[label == l, 1], df_dim5[label == l, 2],
               color=plt.cm.jet(float(l) / np.max(label + 1)),
               s=20, edgecolor='k')
plt.title('With connectivity constraints (time %.2fs)' % elapsed_time)

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# Compute unstructured hierarchical clustering...
# Elapsed time: 0.23s
# Number of points: 3375
# Compute structured hierarchical clustering...
# /Users/roswal/anaconda3/lib/python3.6/site-packages/sklearn/cluster/hierarchical.py:243: UserWarning: the number of connected components of the connectivity matrix is 9 > 1. Completing it to avoid stopping the tree early.
#   affinity='euclidean')
# Elapsed time: 0.38s
# Number of points: 3375

# %% [markdown]
# ### Comparison of algorithms

# %%
import hdbscan
import debacl
import fastcluster
import sklearn.cluster
import scipy.cluster
import sklearn.datasets
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_context('poster')
sns.set_palette('Paired', 10)
sns.set_color_codes()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-4b7a22f97bc2> in <module>()
# ----> 1 import hdbscan
#       2 import debacl
#       3 import fastcluster
#       4 import sklearn.cluster
#       5 import scipy.cluster
#
# ModuleNotFoundError: No module named 'hdbscan'

# %%
def benchmark_algorithm(dataset_sizes, cluster_function, function_args, function_kwds,
                        dataset_dimension=10, dataset_n_clusters=10, max_time=45, sample_size=2):

    # Initialize the result with NaNs so that any unfilled entries
    # will be considered NULL when we convert to a pandas dataframe at the end
    result = np.nan * np.ones((len(dataset_sizes), sample_size))
    for index, size in enumerate(dataset_sizes):
        for s in range(sample_size):
            # Use sklearns make_blobs to generate a random dataset with specified size
            # dimension and number of clusters
            data, labels = sklearn.datasets.make_blobs(n_samples=size,
                                                       n_features=dataset_dimension,
                                                       centers=dataset_n_clusters)

            # Start the clustering with a timer
            start_time = time.time()
            cluster_function(data, *function_args, **function_kwds)
            time_taken = time.time() - start_time

            # If we are taking more than max_time then abort -- we don't
            # want to spend excessive time on slow algorithms
            if time_taken > max_time:
                result[index, s] = time_taken
                return pd.DataFrame(np.vstack([dataset_sizes.repeat(sample_size),
                                               result.flatten()]).T, columns=['x','y'])
            else:
                result[index, s] = time_taken

    # Return the result as a dataframe for easier handling with seaborn afterwards
    return pd.DataFrame(np.vstack([dataset_sizes.repeat(sample_size),
                                   result.flatten()]).T, columns=['x','y'])

# %%
dataset_sizes = np.hstack([np.arange(1, 6) * 500, np.arange(3,7) * 1000, np.arange(4,17) * 2000])

# %%
k_means = sklearn.cluster.KMeans(10)
k_means_data = benchmark_algorithm(dataset_sizes, k_means.fit, (), {})

dbscan = sklearn.cluster.DBSCAN(eps=1.25)
dbscan_data = benchmark_algorithm(dataset_sizes, dbscan.fit, (), {})

#scipy_k_means_data = benchmark_algorithm(dataset_sizes,
                                         #scipy.cluster.vq.kmeans, (10,), {})

#scipy_single_data = benchmark_algorithm(dataset_sizes,
                                        #scipy.cluster.hierarchy.single, (), {})

#fastclust_data = benchmark_algorithm(dataset_sizes,
                                     #fastcluster.linkage_vector, (), {})

#hdbscan_ = hdbscan.HDBSCAN()
#hdbscan_data = benchmark_algorithm(dataset_sizes, hdbscan_.fit, (), {})


agglomerative = sklearn.cluster.AgglomerativeClustering(10)
agg_data = benchmark_algorithm(dataset_sizes,
                               agglomerative.fit, (), {}, sample_size=4)

birch = sklearn.cluster.Birch(branching_factor=50, n_clusters=10, threshold=0.5,compute_labels=True)
birch_data = benchmark_algorithm(dataset_sizes,
                               birch.fit, (), {}, sample_size=4)

gmm = sklearn.mixture.GaussianMixture(n_components=10,covariance_type='full')
gmm_data = benchmark_algorithm(dataset_sizes,
                               gmm.fit, (), {})


#spectral = sklearn.cluster.SpectralClustering(10)
#spectral_data = benchmark_algorithm(dataset_sizes,
                                    #spectral.fit, (), {}, sample_size=6)

#affinity_prop = sklearn.cluster.AffinityPropagation()
#ap_data = benchmark_algorithm(dataset_sizes,
                              #affinity_prop.fit, (), {}, sample_size=3)

# %%
from sklearn.mixture import GaussianMixture as GMM
gmm = GMM(n_components=9,covariance_type='full')

# %%
print sklearn.__version__
